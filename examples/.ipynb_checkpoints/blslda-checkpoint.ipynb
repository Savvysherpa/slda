# %% [markdown]
# # Collapsed Gibbs sampler for binary logistic supervised latent Dirichlet allocation
#
# <div style="display:none">
#   $
#       \DeclareMathOperator{\dir}{Dirichlet}
#       \DeclareMathOperator{\dis}{Discrete}
#       \DeclareMathOperator{\normal}{Normal}
#       \DeclareMathOperator{\ber}{Bernoulli}
#       \DeclareMathOperator{\diag}{diag}
#       \DeclareMathOperator{\Betaf}{B}
#       \DeclareMathOperator{\Gammaf}{\Gamma}
#       \DeclareMathOperator{\PG}{PG}
#       \newcommand{\norm}[1]{\left\| #1 \right\|}
#       \newcommand{\cp}[2]{p \left( #1 \middle| #2 \right)}
#       \newcommand{\cN}[2]{\mathscr{N} \left( #1 \middle| #2 \right)}
#       \newcommand{\cpsi}[2]{\psi \left( #1 \middle| #2 \right)}
#       \newcommand{\cPsi}[2]{\Psi \left( #1 \middle| #2 \right)}
#       \newcommand{\etd}[1]{\mathbf{z}^{(#1)}}
#       \newcommand{\sumetd}{\mathbf{z}}
#       \newcommand{\one}{\mathbf{1}}
#   $
# </div>
#
# Here is the collapsed Gibbs sampler for Zhu et al.'s [improved Bayesian logistic supervised topic model with data augmentation](http://arxiv.org/pdf/1310.2408v1.pdf).  I am building on the [collapsed Gibbs sampler](http://nbviewer.savvysherpa.com/github/gp-0058-clt-at-toys-r-us/relational-topic-models/blob/master/slda.ipynb) I wrote for supervised latent Dirichlet allocation.
#
# The generative model for BLSLDA is as follows:
#
# $$\begin{align}
# \theta^{(d)} &\sim \dir(\alpha) &\text{(topic distribution for document $d \in \{1, \ldots, D\}$)} \\
# \phi^{(k)} &\sim \dir(\beta) &\text{(term distribution for topic $k \in \{1, \ldots, K\}$)} \\
# z_n^{(d)} \mid \theta^{(d)} &\sim \dis \left( \theta^{(d)} \right) &\text{(topic of $n$th token of document $d$, $n \in \{1, \ldots, N^{(d)}\}$)} \\
# w_n^{(d)} \mid \phi^{(z_n^{(d)})} &\sim \dis \left( \phi^{(z_n^{(d)})} \right) &\text{(term of $n$th token of document $d$, $n \in \{1, \ldots, N^{(d)}\}$)} \\
# \eta_k &\sim \normal \left( \mu, \nu^2 \right) &\text{(regression coefficient for topic $k \in \{1, \ldots, K\}$)} \\
# y^{(d)} \mid \eta, \etd{d} &\sim \ber \left( \frac{ \exp \left( \eta \cdot \etd{d} \right) }{ 1 + \exp \left( \eta \cdot \etd{d} \right) } \right) &\text{(response value of document $d \in \{1, \ldots, D\}$)}
# \end{align}$$
#
# where each token can be any one of $V$ terms in our vocabulary, and $\etd{d}$ is the empirical topic distribution of document $d$.
#
# <img src="http://www.mdpi.com/remotesensing/remotesensing-05-02275/article_deploy/html/images/remotesensing-05-02275f2-1024.png" width="400">
#
# <p style='text-align: center; font-style: italic;'>
# Plate notation for supervised latent Dirichlet allocation.
# <br/>
# This diagram should replace $\beta_k$ with $\phi^{(k)}$, and each $\phi^{(k)}$ should be dependent on a single $\beta$.
# </p>
#
# Following [Zhu et al. 2013](http://arxiv.org/pdf/1310.2408v1.pdf), the regularized pseudo-likelihood for the response variable $y^{(d)}$, with regularization parameter $b \ge 0$, can be written
#
# $$\begin{align}
# \cpsi{y^{(d)}}{\eta, \etd{d}, b}
# &= \cp{y^{(d)}}{\eta, \etd{d}}^b
# \\ &= \left( \frac{\exp \left( \eta \cdot \etd{d} \right)^{y^{(d)}}}{ 1 + \exp \left( \eta \cdot \etd{d} \right)} \right)^b
# \\ &= \frac{\exp \left( b y^{(d)} (\eta \cdot \etd{d}) \right)}
# { \left( \exp \left( -\frac{\eta \cdot \etd{d}}{2} \right) + \exp \left( \frac{ \eta \cdot \etd{d} }{2} \right) \right)^b \exp \left( \frac{b}{2} (\eta \cdot \etd{d}) \right) }
# \\ &= 2^{-b} \exp \left( b \left( y^{(d)} - \frac{1}{2} \right) \left( \eta \cdot \etd{d} \right) \right) \cosh \left( \frac{ \eta \cdot \etd{d} }{2} \right)^{-b}
# \\ &= 2^{-b} \exp \left( b \left( y^{(d)} - \frac{1}{2} \right) \left( \eta \cdot \etd{d} \right) \right)
# \int_0^\infty \exp \left( -\frac{ \left( \eta \cdot \etd{d} \right)^2 }{2} \omega^{(d)} \right)
# \cp{\omega^{(d)}}{b, 0} d\omega^{(d)}
# \end{align}$$
#
# where $\omega^{(d)}$ is a Polya-Gamma distributed variable with parameters $b = b$ and $c = 0$ (see [Polson et al. 2012](http://arxiv.org/pdf/1205.0310v3.pdf) for details).  This means that, for each document $d$, the pseudo-likelihood of $y^{(d)}$ is actually a mixture of Gaussians with respect to the Polya-Gamma distribution $\PG(b, 0)$.  Therefore, the joint pseudo-likelihood of $y^{(d)}$ and $\omega^{(d)}$ can be written
#
# $$\cPsi{y^{(d)}, \omega^{(d)}}{\eta, \etd{d}, b}
# = 2^{-b} \exp \left( \kappa^{(d)} \zeta^{(d)} - \frac{ \omega^{(d)} }{2} (\zeta^{(d)})^2 \right) \cp{\omega^{(d)}}{b, 0}.$$
#
# where $\kappa^{(d)} = b(y^{(d)} - 1/2)$ and $\zeta^{(d)} = \eta \cdot \etd{d}$.  The joint probability distribution can therefore be factored as follows:
#
# $$\begin{align}
# \cp{\theta, \phi, z, w, \eta, y, \omega}{\alpha, \beta, \mu, \nu^2, b}
# &=
# \prod_{k=1}^{K} \cp{\phi^{(k)}}{\beta}
# \prod_{d=1}^{D} \cp{\theta^{(d)}}{\alpha}
# \prod_{n=1}^{N^{(d)}} \cp{z_n^{(d)}}{\theta^{(d)}} \cp{w_n^{(d)}}{\phi^{(z_n^{(d)})}}
# \\ & \quad \times \prod_{k'=1}^{K} \cp{\eta_{k'}}{\mu, \nu^2}
# \prod_{d'=1}^D \cPsi{y^{(d')}, \omega^{(d')}}{\eta, \etd{d'}, b}
# \\ &=
# \prod_{k=1}^{K} \frac{\Betaf(b^{(k)} + \beta)}{\Betaf(\beta)} \cp{\phi^{(k)}}{b^{(k)} + \beta}
# \prod_{d=1}^{D} \frac{\Betaf(a^{(d)} + \alpha)}{\Betaf(\alpha)} \cp{\theta^{(d)}}{a^{(d)} + \alpha}
# \\ &\quad \times
# \prod_{k'=1}^{K} \cN{\eta_{k'}}{\mu, \nu^2}
# \prod_{d'=1}^{D} 2^{-b} \exp \left( \kappa^{(d')} \zeta^{(d')} - \frac{ \omega^{(d')} }{2} (\zeta^{(d')})^2 \right) \cp{\omega^{(d')}}{b, 0}
# \end{align}$$
#
# where $a_k^{(d)}$ is the number of tokens in document $d$ assigned to topic $k$, $b_v^{(k)}$ is the number of tokens equal to term $v$ and assigned to topic $k$, and $\Betaf$ is the [multivariate Beta function](https://en.wikipedia.org/wiki/Beta_function#Multivariate_beta_function). Marginalizing out $\theta$ and $\phi$ by integrating with respect to each $\theta^{(d)}$ and $\phi^{(k)}$ over their respective sample spaces yields
#
# $$\begin{align}
# \cp{z, w, \eta, y, \omega}{\alpha, \beta, \mu, \nu^2, b}
# &=
# \prod_{k=1}^{K} \frac{\Betaf(b^{(k)} + \beta)}{\Betaf(\beta)}
# \prod_{d=1}^{D} \frac{\Betaf(a^{(d)} + \alpha)}{\Betaf(\alpha)}
# \prod_{k'=1}^{K} \cN{\eta_{k'}}{\mu, \nu^2}
# \prod_{d'=1}^{D} 2^{-b} \exp \left( \kappa^{(d')} \zeta^{(d')} - \frac{ \omega^{(d')} }{2} (\zeta^{(d')})^2 \right) \cp{\omega^{(d')}}{b, 0}
# \\ &=
# \cp{w}{z, \beta} \cp{z}{\alpha} \cp{\eta}{\mu, \nu^2} \cPsi{y, \omega}{\eta, z, b}.
# \end{align}$$
#
# See my [LDA notebook](http://nbviewer.savvysherpa.com/github/bearnshaw/ml-demos/blob/master/lda_gibbs_sampling_cython.ipynb) for step-by-step details of the previous two calculations.
#
# Our goal is to calculate the posterior distribution
#
# $$\cp{z, \eta, \omega}{w, y, \alpha, \beta, \mu, \nu^2, b} =
# \frac{\cp{z, w, \eta, y, \omega}{\alpha, \beta, \mu, \nu^2, b}}
# {\sum_{z'} \iint \cp{z', w, \eta', y, \omega{'}}{\alpha, \beta, \mu, \nu^2, b} d\eta' d\omega{'}}$$
#
# in order to infer the topic assignments $z$ and regression coefficients $\eta$ from the given term assignments $w$ and response data $y$.  Since calculating this directly is infeasible, we resort to collapsed Gibbs sampling.  The sampler is "collapsed" because we marginalized out $\theta$ and $\phi$, and will estimate them from the topic assignments $z$:
#
# $$\hat\theta_k^{(d)} = \frac{a_k^{(d)} + \alpha_k}{\sum_{k'=1}^K \left(a_{k'}^{(d)} + \alpha_{k'} \right)},\quad
# \hat\phi_v^{(k)} = \frac{b_v^{(k)} + \beta_v}{\sum_{v'=1}^V \left(b_{v'}^{(k)} + \beta_{v'} \right)}.$$
#
# Gibbs sampling requires us to compute the full conditionals for each $z_n^{(d)}$, $\omega^{(d)}$ and $\eta_k$.  For example, we need to calculate, for all $n$, $d$ and $k$,
#
# $$\begin{align}
# \cp{z_n^{(d)} = k}{z \setminus z_n^{(d)}, w, \eta, y, \omega, \alpha, \beta, \mu, \nu^2, b}
# &\propto
# \cp{z_n^{(d)} = k, z \setminus z_n^{(d)}, w, \eta, y, \omega}{\alpha, \beta, \mu, \nu^2, b}
# \\ &\propto
# \frac{b_{w_n^{(d)}}^{(k)} \setminus z_n^{(d)} + \beta_{w_n^{(d)}}}{ \sum_{v=1}^V \left( b_v^{(k)} \setminus z_n^{(d)} + \beta_v\right)}
# \left( a_k^{(d)} \setminus z_n^{(d)} + \alpha_k \right)
# \prod_{d'=1}^{D} \exp \left( \kappa^{(d')} \zeta^{(d')} - \frac{ \omega^{(d')} }{2} (\zeta^{(d')})^2 \right)
# \\ &\propto
# \frac{b_{w_n^{(d)}}^{(k)} \setminus z_n^{(d)} + \beta_{w_n^{(d)}}}{ \sum_{v=1}^V \left( b_v^{(k)} \setminus z_n^{(d)} + \beta_v\right)}
# \left( a_k^{(d)} \setminus z_n^{(d)} + \alpha_k \right)
# \\ &\quad \times \exp \left( \left( \kappa^{(d)} - \omega^{(d)} (\zeta^{(d)} \setminus z_n^{(d)}) \right) \frac{\eta_k}{N^{(d)}}
# - \frac{\omega^{(d)}}{2} \left( \frac{\eta_k}{N^{(d)}} \right)^2 \right)
# \end{align}$$
#
# where the "set-minus" notation $\cdot \setminus z_n^{(d)}$ denotes the variable the notation is applied to with the entry $z_n^{(d)}$ removed (again, see my [LDA notebook](http://nbviewer.savvysherpa.com/github/bearnshaw/ml-demos/blob/master/lda_gibbs_sampling_cython.ipynb) for details).  This final proportionality is true since
#
# $$\begin{align}
# \prod_{d'=1}^{D} \exp \left( \kappa^{(d')} \zeta^{(d')} - \frac{ \omega^{(d')} }{2} (\zeta^{(d')})^2 \right)
# &=
# \prod_{d'=1}^{D} \exp \left( \kappa^{(d')} \left( \zeta^{(d')} \setminus z_n^{(d)} + \delta_{d, d'} \frac{\eta_k}{N^{(d)}} \right)
# - \frac{ \omega^{(d')} }{2} \left( \zeta^{(d')} \setminus z_n^{(d)} + \delta_{d, d'} \frac{\eta_k}{N^{(d)}} \right)^2 \right)
# \\ &\propto
# \exp \left( \kappa^{(d)} \left( \zeta^{(d)} \setminus z_n^{(d)} + \frac{\eta_k}{N^{(d)}} \right)
# - \frac{ \omega^{(d)} }{2} \left( \zeta^{(d)} \setminus z_n^{(d)} + \frac{\eta_k}{N^{(d)}} \right)^2 \right)
# \\ &\propto
# \exp \left( \left( \kappa^{(d)} - \omega^{(d)} (\zeta^{(d)} \setminus z_n^{(d)}) \right) \frac{\eta_k}{N^{(d)}}
# - \frac{\omega^{(d)}}{2} \left( \frac{\eta_k}{N^{(d)}} \right)^2 \right)
# \end{align}$$
#
# where $\delta_{d, d'}$ is the [Kronecker delta](https://en.wikipedia.org/wiki/Kronecker_delta).
#
# In order to calculate the full conditional for $\eta$, let $Z = (\etd{1} \cdots \etd{D})$ be the matrix whose $d$th column is $\etd{d}$, $\Omega = \diag(\omega^{(1)}, \ldots, \omega^{(D)})$ be the diagonal matrix whose $d$th diagonal entry is $\omega^{(d)}$, $I$ be the identity matrix, and $\one$ be the vector of ones, and note that
#
# $$\prod_{k=1}^{K} \cN{\eta_{k}}{\mu, \nu^2} = \cN{\eta}{\mu \one, \nu^2 I}$$
# $$\prod_{d=1}^{D} \exp \left( \kappa^{(d)} \zeta^{(d)} - \frac{ \omega^{(d)} }{2} (\zeta^{(d)})^2 \right)
# = \exp \left( \eta^T Z \kappa - \frac{1}{2} \eta^T Z \Omega Z^T \eta \right)
# \propto \cN{\eta}{(Z \Omega Z^T)^{-1} Z \kappa, (Z \Omega Z^T)^{-1}}.$$
#
# Therefore
#
# $$\begin{align}
# \cp{\eta}{z, w, y, \omega, \alpha, \beta, \mu, \nu^2, b}
# &\propto
# \cp{z, w, \eta, y, \omega}{\alpha, \beta, \mu, \nu^2, b}
# \\ &\propto
# \cN{\eta}{\mu \one, \nu^2 I} \cN{\eta}{(Z \Omega Z^T)^{-1} Z \kappa, (Z \Omega Z^T)^{-1}}
# \\ &\propto
# \cN{\eta}{\Sigma \left( \frac{\mu}{\nu^2} \one + Z \kappa \right), \Sigma}
# \end{align}$$
#
# where $\Sigma^{-1} = \nu^{-2} I + Z \Omega Z^T$ (see Section 8.1.8 of the [Matrix Cookbook](http://www.math.uwaterloo.ca/~hwolkowi/matrixcookbook.pdf)).
#
# We also need to calculate the full conditional for $\omega$.  We calculate
#
# $$\begin{align}
# \cp{\omega}{z, w, \eta, y, \alpha, \beta, \mu, \nu^2, b}
# &\propto
#
# \cp{z, w, \eta, y, \omega}{\alpha, \beta, \mu, \nu^2, b}
# \\ &\propto
# \prod_{d=1}^D \exp \left( - \frac{ \omega^{(d)} }{2} (\zeta^{(d)})^2 \right) \cp{\omega^{(d)}}{b, 0}
# \\ &=
# \prod_{d=1}^D \cp{\omega^{(d)}}{b, \zeta^{(d)}}
# \end{align}$$
#
# that is, $\omega^{(d)} \sim \PG(b, \eta \cdot \etd{d})$ for each $d$.  We sample from the Polya-Gamma distribution according to the method of [Polson et al. 2012](http://arxiv.org/pdf/1205.0310.pdf), implemented for Python 3 in this [code repo](https://github.com/marekpetrik/pypolyagamma).

# %% [markdown]
# ## Graphical test

# %%
# %matplotlib inline

from modules.helpers import plot_images
from functools import partial
from sklearn.metrics import (roc_auc_score, roc_curve)
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

imshow = partial(plt.imshow, cmap='gray', interpolation='nearest', aspect='auto')
sns.set(style='white')

# %% [markdown]
# ### Generate topics
#
# We assume a vocabulary of 25 terms, and create ten "topics", where each topic assigns exactly 5 consecutive terms equal probability.

# %%
V = 25
K = 10
N = 100
D = 1000

# %%
topics = []
topic_base = np.concatenate((np.ones((1, 5)) * 0.2, np.zeros((4, 5))), axis=0).ravel()
for i in range(5):
    topics.append(np.roll(topic_base, i * 5))
topic_base = np.concatenate((np.ones((5, 1)) * 0.2, np.zeros((5, 4))), axis=1).ravel()
for i in range(5):
    topics.append(np.roll(topic_base, i))
topics = np.array(topics)
plt.figure(figsize=(10, 5))
plot_images(plt, topics, (5, 5), layout=(2, 5), figsize=(10, 5))

# %% [markdown]
# ### Generate documents from topics
#
# We generate 1,000 documents from these 10 topics by sampling 1,000 topic distributions, one for each document, from a Dirichlet distribution with parameter $\alpha = (1, \ldots, 1)$.

# %%
alpha = np.repeat(1., K)
np.random.seed(42)
thetas = np.random.dirichlet(alpha, size=D)
topic_assignments = np.array([np.random.choice(range(K), size=100, p=theta)
                              for theta in thetas])
word_assignments = np.array([[np.random.choice(range(V), size=1, p=topics[topic_assignments[d, n]])[0]
                              for n in range(N)] for d in range(D)])
doc_term_matrix = np.array([np.histogram(word_assignments[d], bins=V, range=(0, V - 1))[0] for d in range(D)])
imshow(doc_term_matrix)

# %% [markdown]
# ### Generate responses

# %%
# choose parameter values
mu = 0.
nu2 = 1.
np.random.seed(4)
eta = np.random.normal(loc=mu, scale=nu2, size=K)
print(eta)
# plot histogram of pre-responses
zeta = np.array([np.dot(eta, thetas[i]) for i in range(D)])
_ = plt.hist(zeta, bins=50)
# Out:
# [ 0.05056171  0.49995133 -0.99590893  0.69359851 -0.41830152 -1.58457724
#  -0.64770677  0.59857517  0.33225003 -1.14747663]

# %%
# choose parameter values
y = (zeta >= 0).astype(int)
# plot histogram of responses
print('positive examples {} ({:.1f}%)'.format(y.sum(), y.sum() / D * 100))
_ = plt.hist(y)
# Out:
# positive examples 138 (13.8%)

# %% [markdown]
# ### Estimate parameters

# %%
from lda_cython.topic_models import BLSLDA
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-c66c60d26259> in <module>()
# ----> 1 from lda_cython.topic_models import BLSLDA
#
# /Users/mattburbidge/anaconda3/envs/lda-cython/lib/python3.5/site-packages/lda_cython/__init__.py in <module>()
#       1 from pkg_resources import get_distribution
# ----> 2 from .topic_models import (LDA, SLDA, BLSLDA, GRTM)
#       3
#       4 __version__ = get_distribution('lda-cython').version
#
# /Users/mattburbidge/anaconda3/envs/lda-cython/lib/python3.5/site-packages/lda_cython/topic_models.py in <module>()
#       8 import numpy as np
#       9 from scipy.sparse import issparse
# ---> 10 from ._topic_models import (gibbs_sampler_lda, gibbs_sampler_slda,
#      11                             gibbs_sampler_blslda, gibbs_sampler_grtm,
#      12                             gibbs_sampler_rtm, gibbs_sampler_blhslda,
#
# lda_cython/_topic_models.pyx in init lda_cython._topic_models (lda_cython/_topic_models.c:32143)()
#
# /Users/mattburbidge/anaconda3/envs/lda-cython/lib/python3.5/site-packages/pypolyagamma/__init__.py in <module>()
# ----> 1 from . import pypolyagamma
#       2 from pypolyagamma.pypolyagamma import PyRNG, PyPolyaGamma, pgdrawvpar, get_omp_num_threads
#
# ImportError: dlopen(/Users/mattburbidge/anaconda3/envs/lda-cython/lib/python3.5/site-packages/pypolyagamma/pypolyagamma.cpython-35m-darwin.so, 2): Library not loaded: @rpath/./libgomp.1.dylib
#   Referenced from: /Users/mattburbidge/anaconda3/envs/lda-cython/lib/python3.5/site-packages/pypolyagamma/pypolyagamma.cpython-35m-darwin.so
#   Reason: image not found

# %%
_K = 10
_alpha = alpha
_beta = np.repeat(0.01, V)
_mu = mu
_nu2 = nu2
_b = 7.25
n_iter = 500
blslda = BLSLDA(_K, _alpha, _beta, _mu, _nu2, _b, n_iter, seed=42)

# %%
# %%time
blslda.fit(doc_term_matrix, y)
# Out:
# 2015-08-24 21:51:46.441987 start iterations
# 2015-08-24 21:51:46.748897 0:00:00.306910 elapsed, iter   10, LL -97726.0415, 37.08% change from last
# 2015-08-24 21:51:54.726757 0:00:08.284770 elapsed, iter  300, LL 25115.5275, 0.42% change from last
# 2015-08-24 21:51:54.999600 0:00:08.557613 elapsed, iter  310, LL 24764.2753, -1.40% change from last
# 2015-08-24 21:51:55.269931 0:00:08.827944 elapsed, iter  320, LL 25091.8952, 1.32% change from last
# 2015-08-24 21:51:55.543147 0:00:09.101160 elapsed, iter  330, LL 25515.7933, 1.69% change from last
# 2015-08-24 21:51:55.823767 0:00:09.381780 elapsed, iter  340, LL 25604.3514, 0.35% change from last
# 2015-08-24 21:51:56.093310 0:00:09.651323 elapsed, iter  350, LL 25592.7337, -0.05% change from last
# 2015-08-24 21:51:56.365105 0:00:09.923118 elapsed, iter  360, LL 25711.6631, 0.46% change from last
# 2015-08-24 21:51:56.635401 0:00:10.193414 elapsed, iter  370, LL 25637.3562, -0.29% change from last
# 2015-08-24 21:51:56.916332 0:00:10.474345 elapsed, iter  380, LL 25230.5460, -1.59% change from last
# 2015-08-24 21:51:57.186093 0:00:10.744106 elapsed, iter  390, LL 25150.3624, -0.32% change from last
# 2015-08-24 21:51:57.465532 0:00:11.023545 elapsed, iter  400, LL 25388.1922, 0.95% change from last
# 2015-08-24 21:51:57.752020 0:00:11.310033 elapsed, iter  410, LL 25751.2618, 1.43% change from last
# 2015-08-24 21:51:58.048926 0:00:11.606939 elapsed, iter  420, LL 26075.1021, 1.26% change from last
# 2015-08-24 21:51:58.315672 0:00:11.873685 elapsed, iter  430, LL 25751.7570, -1.24% change from last
# 2015-08-24 21:51:58.585370 0:00:12.143383 elapsed, iter  440, LL 26197.8723, 1.73% change from last
# 2015-08-24 21:51:58.856076 0:00:12.414089 elapsed, iter  450, LL 26390.4878, 0.74% change from last
# 2015-08-24 21:51:59.132118 0:00:12.690131 elapsed, iter  460, LL 25805.8916, -2.22% change from last
# 2015-08-24 21:51:59.401142 0:00:12.959155 elapsed, iter  470, LL 26304.9692, 1.93% change from last
# 2015-08-24 21:51:59.680255 0:00:13.238268 elapsed, iter  480, LL 26700.6544, 1.50% change from last
# 2015-08-24 21:51:59.955556 0:00:13.513569 elapsed, iter  490, LL 26238.4650, -1.73% change from last
# CPU times: user 13.7 s, sys: 41.3 ms, total: 13.7 s
# Wall time: 13.8 s

# %%
plot_images(plt, blslda.phi, (5, 5), (2, 5), figsize=(10, 5))

# %%
topic_order = [1, 7, 0, 3, 6, 4, 9, 5, 2, 8]
plot_images(plt, blslda.phi[topic_order], (5, 5), (2, 5), figsize=(10, 5))

# %%
imshow(blslda.theta)

# %%
plt.plot(blslda.loglikelihoods)

# %%
burn_in = 300 #max(n_iter - 100, int(n_iter / 2))
blslda.loglikelihoods[burn_in:].mean()
# Out:
# 25635.861229760965

# %%
eta_pred = blslda.eta[burn_in:].mean(axis=0)
print(eta_pred)
# Out:
# [-10.2046844   -0.32919142   1.7715393    7.69770083 -14.95961328
#    5.38967261  -4.70075113   5.50790398 -13.1675921  -10.99316695]

# %%
print(eta_pred[topic_order])
print(eta)
# Out:
# [ -0.32919142   5.50790398 -10.2046844    7.69770083  -4.70075113
#  -14.95961328 -10.99316695   5.38967261   1.7715393  -13.1675921 ]
# [ 0.05056171  0.49995133 -0.99590893  0.69359851 -0.41830152 -1.58457724
#  -0.64770677  0.59857517  0.33225003 -1.14747663]

# %% [markdown]
# ### Predict response of test documents

# %% [markdown]
# Create 1,000 test documents using the same generative process as our training documents, and compute their actual responses.

# %%
np.random.seed(42^2)
thetas_test = np.random.dirichlet(alpha, size=D)
topic_assignments_test = np.array([np.random.choice(range(K), size=100, p=theta)
                                   for theta in thetas_test])
word_assignments_test = np.array([[np.random.choice(range(V), size=1, p=topics[topic_assignments_test[d, n]])[0]
                                   for n in range(N)] for d in range(D)])
doc_term_matrix_test = np.array([np.histogram(word_assignments_test[d], bins=V, range=(0, V - 1))[0] for d in range(D)])
y_test = np.array([np.dot(eta, thetas_test[i]) >= 0 for i in range(D)], dtype=int)
imshow(doc_term_matrix_test)

# %% [markdown]
# Estimate their topic distributions using the trained model, then calculate the predicted responses using the mean of our samples of $\eta$ after burn-in as an estimate for $\eta$.

# %%
def bern_param(eta, theta):
    return np.exp(np.dot(eta, theta)) / (1 + np.exp(np.dot(eta, theta)))

# %%
thetas_test_blslda = blslda.transform(doc_term_matrix_test)
y_blslda = [bern_param(eta_pred, thetas_test_blslda[i]) for i in range(D)]
_ = plt.hist(y_blslda, bins=30)

# %% [markdown]
# Measure the goodness of our prediction using [area under the ROC curve](https://en.wikipedia.org/wiki/Receiver_operating_characteristic).

# %%
fpr, tpr, _ = roc_curve(y_test, y_blslda)
plt.plot(fpr, tpr, label=('AUC = {:.3f}'.format(roc_auc_score(y_test, y_blslda))))
_ = plt.legend(loc='best')

# %% [markdown]
# ### Find best b

# %%
_b_grid = np.arange(1, 10, 1)
roc_auc_scores = []
for _b in _b_grid:
    print('Training BLSLDA with b = {}'.format(_b))
    _blslda = BLSLDA(_K, _alpha, _beta, _mu, _nu2, _b, n_iter, seed=42, verbose=False)
    _blslda.fit(doc_term_matrix, y)
    _thetas_test_blslda = _blslda.transform(doc_term_matrix_test)
    _eta_pred = _blslda.eta[burn_in:].mean(axis=0)
    _y_blslda = [bern_param(_eta_pred, _thetas_test_blslda[i]) for i in range(D)]
    roc_auc_scores.append(roc_auc_score(y_test, _y_blslda))
    print('  roc_auc_score = {}'.format(roc_auc_scores[-1]))
print(_b_grid[np.argmax(roc_auc_scores)], np.max(roc_auc_scores))
plt.plot(_b_grid, roc_auc_scores)
# Out:
# Training BLSLDA with b = 1
#   roc_auc_score = 0.9548627527324305
# Training BLSLDA with b = 2
#   roc_auc_score = 0.9570598214534027
# Training BLSLDA with b = 3
#   roc_auc_score = 0.9578941513474428
# Training BLSLDA with b = 4
#   roc_auc_score = 0.9592661605065309
# Training BLSLDA with b = 5
#   roc_auc_score = 0.959423756153183
# Training BLSLDA with b = 6
#   roc_auc_score = 0.9600634090719471
# Training BLSLDA with b = 7
#   roc_auc_score = 0.9602673563793791
# Training BLSLDA with b = 8
#   roc_auc_score = 0.9603415190366271
# Training BLSLDA with b = 9
#   roc_auc_score = 0.9595442704712109
# 8 0.960341519037

# %%
_b_grid = np.arange(7, 8, .1)
roc_auc_scores = []
for _b in _b_grid:
    print('Training BLSLDA with b = {}'.format(_b))
    _blslda = BLSLDA(_K, _alpha, _beta, _mu, _nu2, _b, n_iter, seed=42, verbose=False)
    _blslda.fit(doc_term_matrix, y)
    _thetas_test_blslda = _blslda.transform(doc_term_matrix_test)
    _eta_pred = _blslda.eta[burn_in:].mean(axis=0)
    _y_blslda = [bern_param(_eta_pred, _thetas_test_blslda[i]) for i in range(D)]
    roc_auc_scores.append(roc_auc_score(y_test, _y_blslda))
    print('  roc_auc_score = {}'.format(roc_auc_scores[-1]))
print(_b_grid[np.argmax(roc_auc_scores)], np.max(roc_auc_scores))
plt.plot(_b_grid, roc_auc_scores)
# Out:
# Training BLSLDA with b = 7.0
#   roc_auc_score = 0.9602673563793791
# Training BLSLDA with b = 7.1
#   roc_auc_score = 0.9600541387397911
# Training BLSLDA with b = 7.199999999999999
#   roc_auc_score = 0.960072679404103
# Training BLSLDA with b = 7.299999999999999
#   roc_auc_score = 0.960044868407635
# Training BLSLDA with b = 7.399999999999999
#   roc_auc_score = 0.9600541387397911
# Training BLSLDA with b = 7.499999999999998
#   roc_auc_score = 0.959868732096671
# Training BLSLDA with b = 7.599999999999998
#   roc_auc_score = 0.959405215488871
# Training BLSLDA with b = 7.6999999999999975
#   roc_auc_score = 0.9603415190366271
# Training BLSLDA with b = 7.799999999999997
#   roc_auc_score = 0.9607030619907111
# Training BLSLDA with b = 7.899999999999997
#   roc_auc_score = 0.9606288993334631
# 7.8 0.960703061991

# %% [markdown]
# ### Two-step learning: learn topics, then learn regression

# %%
from lda_cython.topic_models import LDA

# %%
lda = LDA(_K, _alpha, _beta, n_iter, seed=42)

# %%
# %%time
lda.fit(doc_term_matrix)
# Out:
# 2015-08-24 21:58:48.356328 start iterations
# 2015-08-24 21:58:48.489806 0:00:00.133478 elapsed, iter   10, LL -518559.0163, 8.97% change from last
# 2015-08-24 21:58:48.615504 0:00:00.259176 elapsed, iter   20, LL -468960.0555, 9.56% change from last
# 2015-08-24 21:58:48.736378 0:00:00.380050 elapsed, iter   30, LL -445434.0461, 5.02% change from last
# 2015-08-24 21:58:48.851779 0:00:00.495451 elapsed, iter   40, LL -429314.6963, 3.62% change from last
# 2015-08-24 21:58:48.965943 0:00:00.609615 elapsed, iter   50, LL -419699.1884, 2.24% change from last
# 2015-08-24 21:58:49.079828 0:00:00.723500 elapsed, iter   60, LL -415442.5080, 1.01% change from last
# 2015-08-24 21:58:49.194044 0:00:00.837716 elapsed, iter   70, LL -408896.4141, 1.58% change from last
# 2015-08-24 21:58:49.305402 0:00:00.949074 elapsed, iter   80, LL -402998.4074, 1.44% change from last
# 2015-08-24 21:58:49.417071 0:00:01.060743 elapsed, iter   90, LL -398554.0889, 1.10% change from last
# 2015-08-24 21:58:49.533928 0:00:01.177600 elapsed, iter  100, LL -396059.2952, 0.63% change from last
# 2015-08-24 21:58:49.645961 0:00:01.289633 elapsed, iter  110, LL -393946.6660, 0.53% change from last
# 2015-08-24 21:58:49.759052 0:00:01.402724 elapsed, iter  120, LL -393350.3096, 0.15% change from last
# 2015-08-24 21:58:49.872660 0:00:01.516332 elapsed, iter  130, LL -391582.5349, 0.45% change from last
# 2015-08-24 21:58:49.986561 0:00:01.630233 elapsed, iter  140, LL -389979.6403, 0.41% change from last
# 2015-08-24 21:58:53.272692 0:00:04.916364 elapsed, iter  430, LL -388271.5004, -0.16% change from last
# 2015-08-24 21:58:53.387527 0:00:05.031199 elapsed, iter  440, LL -387805.9252, 0.12% change from last
# 2015-08-24 21:58:53.502156 0:00:05.145828 elapsed, iter  450, LL -388152.3984, -0.09% change from last
# 2015-08-24 21:58:53.617320 0:00:05.260992 elapsed, iter  460, LL -388539.1905, -0.10% change from last
# 2015-08-24 21:58:53.730446 0:00:05.374118 elapsed, iter  470, LL -387818.0986, 0.19% change from last
# 2015-08-24 21:58:53.842825 0:00:05.486497 elapsed, iter  480, LL -387694.9035, 0.03% change from last
# 2015-08-24 21:58:53.954478 0:00:05.598150 elapsed, iter  490, LL -387909.3207, -0.06% change from last
# CPU times: user 5.68 s, sys: 19.1 ms, total: 5.7 s
# Wall time: 5.71 s

# %%
plot_images(plt, lda.phi, (5, 5), (2, 5), figsize=(10, 5))

# %%
imshow(lda.theta)

# %%
plt.plot(lda.loglikelihoods)

# %%
thetas_test_lda = lda.transform(doc_term_matrix_test)

# %% [markdown]
# #### L2-regularized logistic regression
#
# - train logistic regression on training data
# - calculate response on test data
# - measure the goodness of prediction using area under the ROC curve

# %%
from sklearn.linear_model import LogisticRegression

# %%
_C_grid = np.arange(0.001, 100, 1)
roc_auc_scores = []
for _C in _C_grid:
    print('Training Logistic Regression with C = {}'.format(_C))
    _lr = LogisticRegression(fit_intercept=False, C=_C)
    _lr.fit(lda.theta, y)
    _y_lr = _lr.predict_proba(thetas_test_lda)[:, 1]
    roc_auc_scores.append(roc_auc_score(y_test, _y_lr))
    print('  roc_auc_score = {}'.format(roc_auc_scores[-1]))
print(_C_grid[np.argmax(roc_auc_scores)], np.max(roc_auc_scores))
plt.plot(_C_grid, roc_auc_scores)
# Out:
# Training Logistic Regression with C = 0.001
#   roc_auc_score = 0.9483318037285277
# Training Logistic Regression with C = 1.001
#   roc_auc_score = 0.95203530142485
# Training Logistic Regression with C = 2.001
#   roc_auc_score = 0.9541767481528862
# Training Logistic Regression with C = 3.0009999999999994
#   roc_auc_score = 0.9552057550222024
# Training Logistic Regression with C = 4.0009999999999994
#   roc_auc_score = 0.9558083266123425
# Training Logistic Regression with C = 5.0009999999999994
#   roc_auc_score = 0.9563181948809225
# Training Logistic Regression with C = 6.0009999999999994
#   roc_auc_score = 0.9567168191636306
# Training Logistic Regression with C = 7.0009999999999994
#   roc_auc_score = 0.9570505511212467
# Training Logistic Regression with C = 8.001
#   roc_auc_score = 0.9572730390929907
# Training Logistic Regression with C = 9.000999999999998
#   roc_auc_score = 0.9573564720823947
# Training Logistic Regression with C = 10.000999999999998
#   roc_auc_score = 0.9575047973968908
# Training Logistic Regression with C = 11.000999999999998
#   roc_auc_score = 0.9576716633756988
# Training Logistic Regression with C = 12.000999999999998
#   roc_auc_score = 0.9577458260329468
# Training Logistic Regression with C = 13.000999999999998
#   roc_auc_score = 0.9577180150364788
# Training Logistic Regression with C = 14.000999999999998
#   roc_auc_score = 0.9578199886901948
# Training Logistic Regression with C = 15.000999999999998
#   roc_auc_score = 0.9578756106831308
# Training Logistic Regression with C = 16.000999999999998
#   roc_auc_score = 0.9579497733403788
# Training Logistic Regression with C = 17.000999999999998
#   roc_auc_score = 0.9580053953333147
# Training Logistic Regression with C = 18.000999999999998
#   roc_auc_score = 0.9580888283227188
# Training Logistic Regression with C = 19.000999999999998
#   roc_auc_score = 0.9581166393191868
# Training Logistic Regression with C = 20.000999999999998
#   roc_auc_score = 0.9580795579905628
# Training Logistic Regression with C = 21.000999999999998
#   roc_auc_score = 0.9581444503156548
# Training Logistic Regression with C = 22.000999999999998
#   roc_auc_score = 0.9582556943015268
# Training Logistic Regression with C = 23.000999999999998
#   roc_auc_score = 0.9582649646336828
# Training Logistic Regression with C = 24.000999999999998
#   roc_auc_score = 0.9582835052979948
# Training Logistic Regression with C = 25.000999999999998
#   roc_auc_score = 0.9582927756301508
# Training Logistic Regression with C = 26.000999999999998
#   roc_auc_score = 0.9582927756301508
# Training Logistic Regression with C = 27.000999999999998
#   roc_auc_score = 0.9583391272909308
# Training Logistic Regression with C = 28.000999999999998
#   roc_auc_score = 0.9583483976230869
# Training Logistic Regression with C = 29.000999999999998
#   roc_auc_score = 0.9583576679552428
# Training Logistic Regression with C = 30.000999999999998
#   roc_auc_score = 0.9584318306124908
# Training Logistic Regression with C = 31.000999999999998
#   roc_auc_score = 0.9583854789517108
# Training Logistic Regression with C = 32.001
#   roc_auc_score = 0.9584225602803348
# Training Logistic Regression with C = 33.00099999999999
#   roc_auc_score = 0.9584503712768029
# Training Logistic Regression with C = 34.00099999999999
#   roc_auc_score = 0.9584411009446469
# Training Logistic Regression with C = 35.00099999999999
#   roc_auc_score = 0.9584318306124908
# Training Logistic Regression with C = 36.00099999999999
#   roc_auc_score = 0.9584689119411148
# Training Logistic Regression with C = 37.00099999999999
#   roc_auc_score = 0.9584874526054268
# Training Logistic Regression with C = 38.00099999999999
#   roc_auc_score = 0.9585430745983629
# Training Logistic Regression with C = 39.00099999999999
#   roc_auc_score = 0.9585523449305189
# Training Logistic Regression with C = 40.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 41.00099999999999
#   roc_auc_score = 0.9585430745983629
# Training Logistic Regression with C = 42.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 43.00099999999999
#   roc_auc_score = 0.9585152636018949
# Training Logistic Regression with C = 44.00099999999999
#   roc_auc_score = 0.9584874526054269
# Training Logistic Regression with C = 45.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 46.00099999999999
#   roc_auc_score = 0.9584967229375828
# Training Logistic Regression with C = 47.00099999999999
#   roc_auc_score = 0.9584967229375828
# Training Logistic Regression with C = 48.00099999999999
#   roc_auc_score = 0.9585059932697388
# Training Logistic Regression with C = 49.00099999999999
#   roc_auc_score = 0.9585430745983629
# Training Logistic Regression with C = 50.00099999999999
#   roc_auc_score = 0.9585152636018949
# Training Logistic Regression with C = 51.00099999999999
#   roc_auc_score = 0.9584967229375828
# Training Logistic Regression with C = 52.00099999999999
#   roc_auc_score = 0.9584874526054268
# Training Logistic Regression with C = 53.00099999999999
#   roc_auc_score = 0.9584781822732709
# Training Logistic Regression with C = 54.00099999999999
#   roc_auc_score = 0.9584596416089588
# Training Logistic Regression with C = 55.00099999999999
#   roc_auc_score = 0.9584318306124908
# Training Logistic Regression with C = 56.00099999999999
#   roc_auc_score = 0.9584411009446467
# Training Logistic Regression with C = 57.00099999999999
#   roc_auc_score = 0.9584411009446469
# Training Logistic Regression with C = 58.00099999999999
#   roc_auc_score = 0.9584596416089588
# Training Logistic Regression with C = 59.00099999999999
#   roc_auc_score = 0.9584503712768029
# Training Logistic Regression with C = 60.00099999999999
#   roc_auc_score = 0.9584503712768029
# Training Logistic Regression with C = 61.00099999999999
#   roc_auc_score = 0.9584503712768029
# Training Logistic Regression with C = 62.00099999999999
#   roc_auc_score = 0.9584596416089588
# Training Logistic Regression with C = 63.00099999999999
#   roc_auc_score = 0.9584781822732709
# Training Logistic Regression with C = 64.00099999999999
#   roc_auc_score = 0.9584689119411148
# Training Logistic Regression with C = 65.00099999999999
#   roc_auc_score = 0.9584781822732709
# Training Logistic Regression with C = 66.00099999999999
#   roc_auc_score = 0.9584874526054268
# Training Logistic Regression with C = 67.00099999999999
#   roc_auc_score = 0.9585152636018948
# Training Logistic Regression with C = 68.00099999999999
#   roc_auc_score = 0.9585245339340508
# Training Logistic Regression with C = 69.00099999999999
#   roc_auc_score = 0.9585338042662068
# Training Logistic Regression with C = 70.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 71.00099999999999
#   roc_auc_score = 0.9585152636018949
# Training Logistic Regression with C = 72.00099999999999
#   roc_auc_score = 0.9585059932697388
# Training Logistic Regression with C = 73.00099999999999
#   roc_auc_score = 0.9585152636018949
# Training Logistic Regression with C = 74.00099999999999
#   roc_auc_score = 0.9585338042662068
# Training Logistic Regression with C = 75.00099999999999
#   roc_auc_score = 0.9585338042662068
# Training Logistic Regression with C = 76.00099999999999
#   roc_auc_score = 0.9585059932697388
# Training Logistic Regression with C = 77.00099999999999
#   roc_auc_score = 0.9585152636018949
# Training Logistic Regression with C = 78.00099999999999
#   roc_auc_score = 0.9585059932697388
# Training Logistic Regression with C = 79.00099999999999
#   roc_auc_score = 0.9584967229375828
# Training Logistic Regression with C = 80.00099999999999
#   roc_auc_score = 0.9584781822732709
# Training Logistic Regression with C = 81.00099999999999
#   roc_auc_score = 0.9584781822732709
# Training Logistic Regression with C = 82.00099999999999
#   roc_auc_score = 0.9585059932697388
# Training Logistic Regression with C = 83.00099999999999
#   roc_auc_score = 0.9585059932697388
# Training Logistic Regression with C = 84.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 85.00099999999999
#   roc_auc_score = 0.9585430745983629
# Training Logistic Regression with C = 86.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 87.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 88.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 89.00099999999999
#   roc_auc_score = 0.9585245339340509
# Training Logistic Regression with C = 90.00099999999999
#   roc_auc_score = 0.9585245339340508
# Training Logistic Regression with C = 91.00099999999999
#   roc_auc_score = 0.9585338042662068
# Training Logistic Regression with C = 92.00099999999999
#   roc_auc_score = 0.9585338042662068
# Training Logistic Regression with C = 93.00099999999999
#   roc_auc_score = 0.9585152636018949
# Training Logistic Regression with C = 94.00099999999999
#   roc_auc_score = 0.9585152636018948
# Training Logistic Regression with C = 95.00099999999999
#   roc_auc_score = 0.9585152636018948
# Training Logistic Regression with C = 96.00099999999999
#   roc_auc_score = 0.9585152636018948
# Training Logistic Regression with C = 97.00099999999999
#   roc_auc_score = 0.9585245339340508
# Training Logistic Regression with C = 98.00099999999999
#   roc_auc_score = 0.9585338042662068
# Training Logistic Regression with C = 99.00099999999999
#   roc_auc_score = 0.9585430745983629
# 39.001 0.958552344931

# %%
lr = LogisticRegression(fit_intercept=False, C=39)
lr.fit(lda.theta, y)
y_lr = lr.predict_proba(thetas_test_lda)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_lr)
plt.plot(fpr, tpr, label=('AUC = {:.3f}'.format(roc_auc_score(y_test, y_lr))))
_ = plt.legend(loc='best')

# %% [markdown]
# #### Gradient boosted trees
#
# - train gradient boosted trees on training data
# - calculate response on test data
# - measure the goodness of prediction using area under the ROC

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbr = GradientBoostingClassifier()
gbr.fit(lda.theta, y)
y_gbr = gbr.predict_proba(thetas_test_lda)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_gbr)
plt.plot(fpr, tpr, label=('AUC = {:.3f}'.format(roc_auc_score(y_test, y_gbr))))
_ = plt.legend(loc='best')

# %% [markdown]
# ### Conclusion
#
# The best BLSLDA is slightly better than the best logistic regression, and better than gradient boosted regression trees.  The similar performance to logistic regression is likely due to the fact that this test was set up as an exact problem - all parameters used in training, except $\beta$ (because we hand-picked the topics) and $\eta$ (because that was the one parameter we wanted to learn), were those used to generate documents.

# %% [markdown]
# ## Test with fewer topics
#
# We now redo the previous test, but this time with fewer topics, in order to determine whether
#
# 1. the supervised portion of BLSLDA will produce topics different from those produced by LDA, and
# 1. prediction with SLDA is improved over LDA-and-a-regression.
#
# Because we will no longer be solving an exact problem (the number of topics, and hence $\alpha$, will both be different from the document generation process), we expect BLSLDA to do better than LDA-and-a-regression, including unregularized linear regression.

# %%
_K = 5
_alpha = np.repeat(1., _K)

# %%
_b_grid = np.arange(1, 10, 1)
roc_auc_scores = []
for _b in _b_grid:
    print('Training BLSLDA with b = {}'.format(_b))
    _blslda = BLSLDA(_K, _alpha, _beta, _mu, _nu2, _b, n_iter, seed=42, verbose=False)
    _blslda.fit(doc_term_matrix, y)
    _thetas_test_blslda = _blslda.transform(doc_term_matrix_test)
    _eta_pred = _blslda.eta[burn_in:].mean(axis=0)
    _y_blslda = [bern_param(_eta_pred, _thetas_test_blslda[i]) for i in range(D)]
    roc_auc_scores.append(roc_auc_score(y_test, _y_blslda))
    print('  roc_auc_score = {}'.format(roc_auc_scores[-1]))
print(_b_grid[np.argmax(roc_auc_scores)], np.max(roc_auc_scores))
plt.plot(_b_grid, roc_auc_scores)
# Out:
# Training BLSLDA with b = 1
#   roc_auc_score = 0.8404205022665963
# Training BLSLDA with b = 2
#   roc_auc_score = 0.8907120542129024
# Training BLSLDA with b = 3
#   roc_auc_score = 0.927598705861631
# Training BLSLDA with b = 4
#   roc_auc_score = 0.9475948123221255
# Training BLSLDA with b = 5
#   roc_auc_score = 0.9507652659194779
# Training BLSLDA with b = 6
#   roc_auc_score = 0.9340323163778959
# Training BLSLDA with b = 7
#   roc_auc_score = 0.9478821926189616
# Training BLSLDA with b = 8
#   roc_auc_score = 0.9360717894522161
# Training BLSLDA with b = 9
#   roc_auc_score = 0.9512844045202139
# 9 0.95128440452

# %%
_b_grid = np.arange(9, 11, 0.2)
roc_auc_scores = []
for _b in _b_grid:
    print('Training BLSLDA with b = {}'.format(_b))
    _blslda = BLSLDA(_K, _alpha, _beta, _mu, _nu2, _b, n_iter, seed=42, verbose=False)
    _blslda.fit(doc_term_matrix, y)
    _thetas_test_blslda = _blslda.transform(doc_term_matrix_test)
    _eta_pred = _blslda.eta[burn_in:].mean(axis=0)
    _y_blslda = [bern_param(_eta_pred, _thetas_test_blslda[i]) for i in range(D)]
    roc_auc_scores.append(roc_auc_score(y_test, _y_blslda))
    print('  roc_auc_score = {}'.format(roc_auc_scores[-1]))
print(_b_grid[np.argmax(roc_auc_scores)], np.max(roc_auc_scores))
plt.plot(_b_grid, roc_auc_scores)
# Out:
# Training BLSLDA with b = 9.0
#   roc_auc_score = 0.9512844045202139
# Training BLSLDA with b = 9.2
#   roc_auc_score = 0.9400394916149846
# Training BLSLDA with b = 9.399999999999999
#   roc_auc_score = 0.9508579692410378
# Training BLSLDA with b = 9.599999999999998
#   roc_auc_score = 0.9494210677568576
# Training BLSLDA with b = 9.799999999999997
#   roc_auc_score = 0.9232694607447784
# Training BLSLDA with b = 9.999999999999996
#   roc_auc_score = 0.9345699956429439
# Training BLSLDA with b = 10.199999999999996
#   roc_auc_score = 0.9270424859322709
# Training BLSLDA with b = 10.399999999999995
#   roc_auc_score = 0.951238052859434
# Training BLSLDA with b = 10.599999999999994
#   roc_auc_score = 0.9490966061313977
# Training BLSLDA with b = 10.799999999999994
#   roc_auc_score = 0.9479285442797415
# 9.0 0.95128440452

# %%
_b = 9
n_iter = 1000
blslda1 = BLSLDA(_K, _alpha, _beta, _mu, _nu2, _b, n_iter, seed=42)

# %%
# %%time
blslda1.fit(doc_term_matrix, y)
# Out:
# 2015-08-24 22:12:15.238120 start iterations
# 2015-08-24 22:12:15.425505 0:00:00.187385 elapsed, iter   10, LL -59627.4288, 42.74% change from last
# 2015-08-24 22:12:15.587324 0:00:00.349204 elapsed, iter   20, LL -38485.2356, 35.46% change from last
# 2015-08-24 22:12:15.742121 0:00:00.504001 elapsed, iter   30, LL -30896.5567, 19.72% change from last
# 2015-08-24 22:12:15.900520 0:00:00.662400 elapsed, iter   40, LL -26377.3264, 14.63% change from last
# 2015-08-24 22:12:16.056361 0:00:00.818241 elapsed, iter   50, LL -25061.2398, 4.99% change from last
# 2015-08-24 22:12:16.211115 0:00:00.972995 elapsed, iter   60, LL -22499.3823, 10.22% change from last
# 2015-08-24 22:12:16.363927 0:00:01.125807 elapsed, iter   70, LL -22585.6477, -0.38% change from last
# 2015-08-24 22:12:16.521053 0:00:01.282933 elapsed, iter   80, LL -21046.8243, 6.81% change from last
# 2015-08-24 22:12:16.676518 0:00:01.438398 elapsed, iter   90, LL -21066.6640, -0.09% change from last
# 2015-08-24 22:12:16.833665 0:00:01.595545 elapsed, iter  100, LL -20939.1338, 0.61% change from last
# 2015-08-24 22:12:16.989367 0:00:01.751247 elapsed, iter  110, LL -19995.1649, 4.51% change from last
# 2015-08-24 22:12:17.143013 0:00:01.904893 elapsed, iter  120, LL -19198.2887, 3.99% change from last
# 2015-08-24 22:12:17.296108 0:00:02.057988 elapsed, iter  130, LL -19704.0405, -2.63% change from last
# 2015-08-24 22:12:17.450552 0:00:02.212432 elapsed, iter  140, LL -19936.5140, -1.18% change from last
# 2015-08-24 22:12:17.609628 0:00:02.371508 elapsed, iter  150, LL -20752.0779, -4.09% change from last
# CPU times: user 15.7 s, sys: 45.8 ms, total: 15.7 s
# Wall time: 15.8 s

# %%
plot_images(plt, blslda1.phi, (5, 5), (1, 5), figsize=(10, 5))

# %%
imshow(blslda1.theta)

# %%
plt.plot(blslda1.loglikelihoods)

# %%
burn_in1 = 600
blslda1.loglikelihoods[burn_in1:].mean()
# Out:
# -9680.0354157982511

# %%
eta_pred1 = blslda1.eta[burn_in1:].mean(axis=0)
eta_pred1
# Out:
# array([-17.06091041,   6.55677592,   4.08171512, -16.52803164,   0.76957989])

# %%
thetas_test_blslda1 = blslda1.transform(doc_term_matrix_test)
y_blslda1 = [bern_param(eta_pred1, thetas_test_blslda1[i]) for i in range(D)]

# %%
fpr, tpr, _ = roc_curve(y_test, y_blslda1)
plt.plot(fpr, tpr, label=('AUC = {:.3f}'.format(roc_auc_score(y_test, y_blslda1))))
_ = plt.legend(loc='best')

# %%
lda1 = LDA(_K, _alpha, _beta, n_iter, seed=42)

# %%
# %%time
lda1.fit(doc_term_matrix)
# Out:
# 2015-08-24 22:13:15.067230 start iterations
# 2015-08-24 22:13:15.139618 0:00:00.072388 elapsed, iter   10, LL -449858.6636, 7.31% change from last
# 2015-08-24 22:13:15.205143 0:00:00.137913 elapsed, iter   20, LL -421499.7112, 6.30% change from last
# 2015-08-24 22:13:15.269763 0:00:00.202533 elapsed, iter   30, LL -412836.6038, 2.06% change from last
# 2015-08-24 22:13:15.336310 0:00:00.269080 elapsed, iter   40, LL -407803.7467, 1.22% change from last
# 2015-08-24 22:13:15.400254 0:00:00.333024 elapsed, iter   50, LL -404616.5925, 0.78% change from last
# 2015-08-24 22:13:15.461088 0:00:00.393858 elapsed, iter   60, LL -403503.4904, 0.28% change from last
# 2015-08-24 22:13:15.524428 0:00:00.457198 elapsed, iter   70, LL -402774.9617, 0.18% change from last
# 2015-08-24 22:13:15.587404 0:00:00.520174 elapsed, iter   80, LL -400410.5351, 0.59% change from last
# 2015-08-24 22:13:15.648484 0:00:00.581254 elapsed, iter   90, LL -398969.2767, 0.36% change from last
# 2015-08-24 22:13:15.711163 0:00:00.643933 elapsed, iter  100, LL -398795.2216, 0.04% change from last
# 2015-08-24 22:13:15.772031 0:00:00.704801 elapsed, iter  110, LL -397000.2023, 0.45% change from last
# 2015-08-24 22:13:15.834168 0:00:00.766938 elapsed, iter  120, LL -396616.6913, 0.10% change from last
# 2015-08-24 22:13:15.896227 0:00:00.828997 elapsed, iter  130, LL -396632.0854, -0.00% change from last
# 2015-08-24 22:13:15.958454 0:00:00.891224 elapsed, iter  140, LL -396221.5928, 0.10% change from last
# 2015-08-24 22:13:16.020312 0:00:00.953082 elapsed, iter  150, LL -395896.9934, 0.08% change from last
# 2015-08-24 22:13:16.081846 0:00:01.014616 elapsed, iter  160, LL -395224.6608, 0.17% change from last
# 2015-08-24 22:13:16.143757 0:00:01.076527 elapsed, iter  170, LL -395861.5567, -0.16% change from last
# 2015-08-24 22:13:16.203980 0:00:01.136750 elapsed, iter  180, LL -395439.6530, 0.11% change from last
# 2015-08-24 22:13:16.268082 0:00:01.200852 elapsed, iter  190, LL -395061.2550, 0.10% change from last
# 2015-08-24 22:13:18.069507 0:00:03.002277 elapsed, iter  480, LL -391001.1856, 0.09% change from last
# 2015-08-24 22:13:18.133002 0:00:03.065772 elapsed, iter  490, LL -389983.3385, 0.26% change from last
# 2015-08-24 22:13:18.195610 0:00:03.128380 elapsed, iter  500, LL -389256.3177, 0.19% change from last
# 2015-08-24 22:13:18.258621 0:00:03.191391 elapsed, iter  510, LL -390272.0920, -0.26% change from last
# 2015-08-24 22:13:18.323683 0:00:03.256453 elapsed, iter  520, LL -389816.0872, 0.12% change from last
# 2015-08-24 22:13:18.385979 0:00:03.318749 elapsed, iter  530, LL -389370.2873, 0.11% change from last
# 2015-08-24 22:13:18.448206 0:00:03.380976 elapsed, iter  540, LL -390112.9194, -0.19% change from last
# 2015-08-24 22:13:18.511525 0:00:03.444295 elapsed, iter  550, LL -389885.5813, 0.06% change from last
# 2015-08-24 22:13:18.572614 0:00:03.505384 elapsed, iter  560, LL -390130.3289, -0.06% change from last
# 2015-08-24 22:13:18.634251 0:00:03.567021 elapsed, iter  570, LL -390462.6065, -0.09% change from last
# 2015-08-24 22:13:18.695971 0:00:03.628741 elapsed, iter  580, LL -390693.0102, -0.06% change from last
# 2015-08-24 22:13:18.758906 0:00:03.691676 elapsed, iter  590, LL -389981.0298, 0.18% change from last
# 2015-08-24 22:13:18.821645 0:00:03.754415 elapsed, iter  600, LL -389778.5751, 0.05% change from last
# 2015-08-24 22:13:18.884983 0:00:03.817753 elapsed, iter  610, LL -389740.0401, 0.01% change from last
# 2015-08-24 22:13:18.947205 0:00:03.879975 elapsed, iter  620, LL -389666.9396, 0.02% change from last
# 2015-08-24 22:13:19.009008 0:00:03.941778 elapsed, iter  630, LL -389839.9559, -0.04% change from last
# 2015-08-24 22:13:19.069400 0:00:04.002170 elapsed, iter  640, LL -390903.9558, -0.27% change from last
# 2015-08-24 22:13:19.131398 0:00:04.064168 elapsed, iter  650, LL -390759.0523, 0.04% change from last
# 2015-08-24 22:13:19.192026 0:00:04.124796 elapsed, iter  660, LL -391008.6336, -0.06% change from last
# 2015-08-24 22:13:19.257227 0:00:04.189997 elapsed, iter  670, LL -390991.5179, 0.00% change from last
# 2015-08-24 22:13:19.319286 0:00:04.252056 elapsed, iter  680, LL -390850.6786, 0.04% change from last
# 2015-08-24 22:13:19.380844 0:00:04.313614 elapsed, iter  690, LL -390610.5165, 0.06% change from last
# 2015-08-24 22:13:19.444568 0:00:04.377338 elapsed, iter  700, LL -391153.8288, -0.14% change from last
# 2015-08-24 22:13:19.504971 0:00:04.437741 elapsed, iter  710, LL -390046.3986, 0.28% change from last
# 2015-08-24 22:13:19.568290 0:00:04.501060 elapsed, iter  720, LL -390236.3334, -0.05% change from last
# 2015-08-24 22:13:19.628741 0:00:04.561511 elapsed, iter  730, LL -389750.3991, 0.12% change from last
# 2015-08-24 22:13:19.691492 0:00:04.624262 elapsed, iter  740, LL -390119.4804, -0.09% change from last
# 2015-08-24 22:13:19.752047 0:00:04.684817 elapsed, iter  750, LL -390259.3051, -0.04% change from last
# 2015-08-24 22:13:19.813564 0:00:04.746334 elapsed, iter  760, LL -390970.1584, -0.18% change from last
# 2015-08-24 22:13:19.875369 0:00:04.808139 elapsed, iter  770, LL -390666.7310, 0.08% change from last
# 2015-08-24 22:13:19.935831 0:00:04.868601 elapsed, iter  780, LL -390987.7274, -0.08% change from last
# 2015-08-24 22:13:19.996997 0:00:04.929767 elapsed, iter  790, LL -390042.1833, 0.24% change from last
# 2015-08-24 22:13:20.059645 0:00:04.992415 elapsed, iter  800, LL -389943.0750, 0.03% change from last
# 2015-08-24 22:13:20.120514 0:00:05.053284 elapsed, iter  810, LL -389711.6082, 0.06% change from last
# 2015-08-24 22:13:20.180786 0:00:05.113556 elapsed, iter  820, LL -389047.0562, 0.17% change from last
# 2015-08-24 22:13:20.241295 0:00:05.174065 elapsed, iter  830, LL -389271.4261, -0.06% change from last
# 2015-08-24 22:13:20.303729 0:00:05.236499 elapsed, iter  840, LL -388369.0839, 0.23% change from last
# 2015-08-24 22:13:20.364414 0:00:05.297184 elapsed, iter  850, LL -389463.9210, -0.28% change from last
# 2015-08-24 22:13:20.425431 0:00:05.358201 elapsed, iter  860, LL -390042.1606, -0.15% change from last
# 2015-08-24 22:13:20.487807 0:00:05.420577 elapsed, iter  870, LL -389908.0971, 0.03% change from last
# 2015-08-24 22:13:20.549102 0:00:05.481872 elapsed, iter  880, LL -389594.2356, 0.08% change from last
# 2015-08-24 22:13:20.610317 0:00:05.543087 elapsed, iter  890, LL -389316.6682, 0.07% change from last
# 2015-08-24 22:13:20.671110 0:00:05.603880 elapsed, iter  900, LL -389160.4368, 0.04% change from last
# 2015-08-24 22:13:20.732544 0:00:05.665314 elapsed, iter  910, LL -389423.5651, -0.07% change from last
# 2015-08-24 22:13:20.794296 0:00:05.727066 elapsed, iter  920, LL -388963.9143, 0.12% change from last
# 2015-08-24 22:13:20.853692 0:00:05.786462 elapsed, iter  930, LL -388586.1950, 0.10% change from last
# 2015-08-24 22:13:20.915600 0:00:05.848370 elapsed, iter  940, LL -388375.3405, 0.05% change from last
# 2015-08-24 22:13:20.976211 0:00:05.908981 elapsed, iter  950, LL -388331.8868, 0.01% change from last
# 2015-08-24 22:13:21.036423 0:00:05.969193 elapsed, iter  960, LL -389432.1197, -0.28% change from last
# 2015-08-24 22:13:21.100320 0:00:06.033090 elapsed, iter  970, LL -388987.4901, 0.11% change from last
# 2015-08-24 22:13:21.162742 0:00:06.095512 elapsed, iter  980, LL -389164.3778, -0.05% change from last
# 2015-08-24 22:13:21.223713 0:00:06.156483 elapsed, iter  990, LL -388802.6679, 0.09% change from last
# CPU times: user 6.19 s, sys: 24.6 ms, total: 6.21 s
# Wall time: 6.22 s

# %%
plot_images(plt, lda1.phi, (5, 5), (1, 5), figsize=(10, 5))

# %% [markdown]
# We plot the SLDA topics again and note that they are indeed different!

# %%
plot_images(plt, blslda1.phi, (5, 5), (1, 5), figsize=(10, 5))

# %%
imshow(lda1.theta)

# %%
plt.plot(lda1.loglikelihoods)

# %%
thetas_test_lda1 = lda1.transform(doc_term_matrix_test)

# %% [markdown]
# #### L2-regularized linear regression

# %%
_C_grid = np.arange(0.001, 100, 1)
roc_auc_scores = []
for _C in _C_grid:
    print('Training Logistic Regression with C = {}'.format(_C))
    _lr = LogisticRegression(fit_intercept=False, C=_C)
    _lr.fit(lda1.theta, y)
    _y_lr = _lr.predict_proba(thetas_test_lda1)[:, 1]
    roc_auc_scores.append(roc_auc_score(y_test, _y_lr))
    print('  roc_auc_score = {}'.format(roc_auc_scores[-1]))
print(_C_grid[np.argmax(roc_auc_scores)], np.max(roc_auc_scores))
plt.plot(_C_grid, roc_auc_scores)
# Out:
# Training Logistic Regression with C = 0.001
#   roc_auc_score = 0.7394109630948078
# Training Logistic Regression with C = 1.001
#   roc_auc_score = 0.7842052080726053
# Training Logistic Regression with C = 2.001
#   roc_auc_score = 0.7867452790833496
# Training Logistic Regression with C = 3.0009999999999994
#   roc_auc_score = 0.7878113672812896
# Training Logistic Regression with C = 4.0009999999999994
#   roc_auc_score = 0.7884232092035858
# Training Logistic Regression with C = 5.0009999999999994
#   roc_auc_score = 0.7885715345180817
# Training Logistic Regression with C = 6.0009999999999994
#   roc_auc_score = 0.7888867258113857
# Training Logistic Regression with C = 7.0009999999999994
#   roc_auc_score = 0.7891370247795979
# Training Logistic Regression with C = 8.001
#   roc_auc_score = 0.7891277544474418
# Training Logistic Regression with C = 9.000999999999998
#   roc_auc_score = 0.7891833764403778
# Training Logistic Regression with C = 10.000999999999998
#   roc_auc_score = 0.7891833764403778
# Training Logistic Regression with C = 11.000999999999998
#   roc_auc_score = 0.7893224314227179
# Training Logistic Regression with C = 12.000999999999998
#   roc_auc_score = 0.7893038907584058
# Training Logistic Regression with C = 13.000999999999998
#   roc_auc_score = 0.7893317017548739
# Training Logistic Regression with C = 14.000999999999998
#   roc_auc_score = 0.7893224314227179
# Training Logistic Regression with C = 15.000999999999998
#   roc_auc_score = 0.7893548775852638
# Training Logistic Regression with C = 16.000999999999998
#   roc_auc_score = 0.7894151347442778
# Training Logistic Regression with C = 17.000999999999998
#   roc_auc_score = 0.7894336754085898
# Training Logistic Regression with C = 18.000999999999998
#   roc_auc_score = 0.7894151347442778
# Training Logistic Regression with C = 19.000999999999998
#   roc_auc_score = 0.7894522160729018
# Training Logistic Regression with C = 20.000999999999998
#   roc_auc_score = 0.7895449193944618
# Training Logistic Regression with C = 21.000999999999998
#   roc_auc_score = 0.789591271055242
# Training Logistic Regression with C = 22.000999999999998
#   roc_auc_score = 0.7896283523838659
# Training Logistic Regression with C = 23.000999999999998
#   roc_auc_score = 0.7896468930481779
# Training Logistic Regression with C = 24.000999999999998
#   roc_auc_score = 0.7895912710552419
# Training Logistic Regression with C = 25.000999999999998
#   roc_auc_score = 0.7896005413873979
# Training Logistic Regression with C = 26.000999999999998
#   roc_auc_score = 0.78966543371249
# Training Logistic Regression with C = 27.000999999999998
#   roc_auc_score = 0.78966543371249
# Training Logistic Regression with C = 28.000999999999998
#   roc_auc_score = 0.7896839743768018
# Training Logistic Regression with C = 29.000999999999998
#   roc_auc_score = 0.789693244708958
# Training Logistic Regression with C = 30.000999999999998
#   roc_auc_score = 0.7897117853732699
# Training Logistic Regression with C = 31.000999999999998
#   roc_auc_score = 0.7896932447089579
# Training Logistic Regression with C = 32.001
#   roc_auc_score = 0.7897117853732699
# Training Logistic Regression with C = 33.00099999999999
#   roc_auc_score = 0.7897025150411139
# Training Logistic Regression with C = 34.00099999999999
#   roc_auc_score = 0.7897303260375819
# Training Logistic Regression with C = 35.00099999999999
#   roc_auc_score = 0.789739596369738
# Training Logistic Regression with C = 36.00099999999999
#   roc_auc_score = 0.7897303260375819
# Training Logistic Regression with C = 37.00099999999999
#   roc_auc_score = 0.7897303260375819
# Training Logistic Regression with C = 38.00099999999999
#   roc_auc_score = 0.7897025150411139
# Training Logistic Regression with C = 39.00099999999999
#   roc_auc_score = 0.7897117853732698
# Training Logistic Regression with C = 40.00099999999999
#   roc_auc_score = 0.7897210557054258
# Training Logistic Regression with C = 41.00099999999999
#   roc_auc_score = 0.7897117853732698
# Training Logistic Regression with C = 42.00099999999999
#   roc_auc_score = 0.7897117853732698
# Training Logistic Regression with C = 43.00099999999999
#   roc_auc_score = 0.7897025150411139
# Training Logistic Regression with C = 44.00099999999999
#   roc_auc_score = 0.7897395963697379
# Training Logistic Regression with C = 45.00099999999999
#   roc_auc_score = 0.7897674073662059
# Training Logistic Regression with C = 46.00099999999999
#   roc_auc_score = 0.7897859480305179
# Training Logistic Regression with C = 47.00099999999999
#   roc_auc_score = 0.7898044886948299
# Training Logistic Regression with C = 48.00099999999999
#   roc_auc_score = 0.7898322996912979
# Training Logistic Regression with C = 49.00099999999999
#   roc_auc_score = 0.789860110687766
# Training Logistic Regression with C = 50.00099999999999
#   roc_auc_score = 0.7898786513520779
# Training Logistic Regression with C = 51.00099999999999
#   roc_auc_score = 0.789887921684234
# Training Logistic Regression with C = 52.00099999999999
#   roc_auc_score = 0.7898879216842339
# Training Logistic Regression with C = 53.00099999999999
#   roc_auc_score = 0.7898879216842339
# Training Logistic Regression with C = 54.00099999999999
#   roc_auc_score = 0.78989719201639
# Training Logistic Regression with C = 55.00099999999999
#   roc_auc_score = 0.7898879216842339
# Training Logistic Regression with C = 56.00099999999999
#   roc_auc_score = 0.7898786513520779
# Training Logistic Regression with C = 57.00099999999999
#   roc_auc_score = 0.7898879216842339
# Training Logistic Regression with C = 58.00099999999999
#   roc_auc_score = 0.7898786513520779
# Training Logistic Regression with C = 59.00099999999999
#   roc_auc_score = 0.7898693810199219
# Training Logistic Regression with C = 60.00099999999999
#   roc_auc_score = 0.7898508403556099
# Training Logistic Regression with C = 61.00099999999999
#   roc_auc_score = 0.7898508403556099
# Training Logistic Regression with C = 62.00099999999999
#   roc_auc_score = 0.789869381019922
# Training Logistic Regression with C = 63.00099999999999
#   roc_auc_score = 0.789860110687766
# Training Logistic Regression with C = 64.00099999999999
#   roc_auc_score = 0.7898693810199219
# Training Logistic Regression with C = 65.00099999999999
#   roc_auc_score = 0.7898879216842338
# Training Logistic Regression with C = 66.00099999999999
#   roc_auc_score = 0.7898879216842338
# Training Logistic Regression with C = 67.00099999999999
#   roc_auc_score = 0.7898879216842338
# Training Logistic Regression with C = 68.00099999999999
#   roc_auc_score = 0.7898601106877658
# Training Logistic Regression with C = 69.00099999999999
#   roc_auc_score = 0.7898601106877658
# Training Logistic Regression with C = 70.00099999999999
#   roc_auc_score = 0.7898601106877658
# Training Logistic Regression with C = 71.00099999999999
#   roc_auc_score = 0.7898786513520779
# Training Logistic Regression with C = 72.00099999999999
#   roc_auc_score = 0.7898879216842339
# Training Logistic Regression with C = 73.00099999999999
#   roc_auc_score = 0.7898879216842339
# Training Logistic Regression with C = 74.00099999999999
#   roc_auc_score = 0.78989719201639
# Training Logistic Regression with C = 75.00099999999999
#   roc_auc_score = 0.7899064623485459
# Training Logistic Regression with C = 76.00099999999999
#   roc_auc_score = 0.7899157326807018
# Training Logistic Regression with C = 77.00099999999999
#   roc_auc_score = 0.7899064623485459
# Training Logistic Regression with C = 78.00099999999999
#   roc_auc_score = 0.78989719201639
# Training Logistic Regression with C = 79.00099999999999
#   roc_auc_score = 0.7899064623485459
# Training Logistic Regression with C = 80.00099999999999
#   roc_auc_score = 0.7899064623485459
# Training Logistic Regression with C = 81.00099999999999
#   roc_auc_score = 0.7899342733450139
# Training Logistic Regression with C = 82.00099999999999
#   roc_auc_score = 0.789925003012858
# Training Logistic Regression with C = 83.00099999999999
#   roc_auc_score = 0.7899203678467799
# Training Logistic Regression with C = 84.00099999999999
#   roc_auc_score = 0.789925003012858
# Training Logistic Regression with C = 85.00099999999999
#   roc_auc_score = 0.789925003012858
# Training Logistic Regression with C = 86.00099999999999
#   roc_auc_score = 0.7899342733450139
# Training Logistic Regression with C = 87.00099999999999
#   roc_auc_score = 0.7899435436771699
# Training Logistic Regression with C = 88.00099999999999
#   roc_auc_score = 0.7899435436771699
# Training Logistic Regression with C = 89.00099999999999
#   roc_auc_score = 0.7899435436771699
# Training Logistic Regression with C = 90.00099999999999
#   roc_auc_score = 0.7899435436771699
# Training Logistic Regression with C = 91.00099999999999
#   roc_auc_score = 0.7899435436771699
# Training Logistic Regression with C = 92.00099999999999
#   roc_auc_score = 0.7899528140093259
# Training Logistic Regression with C = 93.00099999999999
#   roc_auc_score = 0.789962084341482
# Training Logistic Regression with C = 94.00099999999999
#   roc_auc_score = 0.7899528140093259
# Training Logistic Regression with C = 95.00099999999999
#   roc_auc_score = 0.789962084341482
# Training Logistic Regression with C = 96.00099999999999
#   roc_auc_score = 0.789962084341482
# Training Logistic Regression with C = 97.00099999999999
#   roc_auc_score = 0.789962084341482
# Training Logistic Regression with C = 98.00099999999999
#   roc_auc_score = 0.789962084341482
# Training Logistic Regression with C = 99.00099999999999
#   roc_auc_score = 0.789962084341482
# 93.001 0.789962084341

# %%
lr1 = LogisticRegression(fit_intercept=False, C=93)
lr1.fit(lda1.theta, y)
y_lr1 = lr1.predict_proba(thetas_test_lda1)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_lr1)
plt.plot(fpr, tpr, label=('AUC = {:.3f}'.format(roc_auc_score(y_test, y_lr1))))
_ = plt.legend(loc='best')

# %% [markdown]
# #### Gradient boosted trees

# %%
gbr1 = GradientBoostingClassifier()
gbr1.fit(lda1.theta, y)
y_gbr1 = gbr1.predict_proba(thetas_test_lda1)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_gbr1)
plt.plot(fpr, tpr, label=('AUC = {:.3f}'.format(roc_auc_score(y_test, y_gbr1))))
_ = plt.legend(loc='best')

# %% [markdown]
# #### L2-regularized logistic regression with SLDA topics

# %%
_C_grid = np.arange(0.001, 100, 1)
roc_auc_scores = []
for _C in _C_grid:
    print('Training Logistic Regression with C = {}'.format(_C))
    _lr = LogisticRegression(fit_intercept=False, C=_C)
    _lr.fit(blslda1.theta, y)
    _y_lr = _lr.predict_proba(thetas_test_blslda1)[:, 1]
    roc_auc_scores.append(roc_auc_score(y_test, _y_lr))
    print('  roc_auc_score = {}'.format(roc_auc_scores[-1]))
print(_C_grid[np.argmax(roc_auc_scores)], np.max(roc_auc_scores))
plt.plot(_C_grid, roc_auc_scores)
# Out:
# Training Logistic Regression with C = 0.001
#   roc_auc_score = 0.9435344068377971
# Training Logistic Regression with C = 1.001
#   roc_auc_score = 0.9490409841384616
# Training Logistic Regression with C = 2.001
#   roc_auc_score = 0.9495693930713538
# Training Logistic Regression with C = 3.0009999999999994
#   roc_auc_score = 0.9499309360254378
# Training Logistic Regression with C = 4.0009999999999994
#   roc_auc_score = 0.9500421800113098
# Training Logistic Regression with C = 5.0009999999999994
#   roc_auc_score = 0.9502090459901178
# Training Logistic Regression with C = 6.0009999999999994
#   roc_auc_score = 0.9502832086473658
# Training Logistic Regression with C = 7.0009999999999994
#   roc_auc_score = 0.9503944526332379
# Training Logistic Regression with C = 8.001
#   roc_auc_score = 0.9504129932975498
# Training Logistic Regression with C = 9.000999999999998
#   roc_auc_score = 0.9504037229653937
# Training Logistic Regression with C = 10.000999999999998
#   roc_auc_score = 0.9503851823010818
# Training Logistic Regression with C = 11.000999999999998
#   roc_auc_score = 0.9504686152904858
# Training Logistic Regression with C = 12.000999999999998
#   roc_auc_score = 0.9504408042940178
# Training Logistic Regression with C = 13.000999999999998
#   roc_auc_score = 0.9503944526332379
# Training Logistic Regression with C = 14.000999999999998
#   roc_auc_score = 0.9504408042940178
# Training Logistic Regression with C = 15.000999999999998
#   roc_auc_score = 0.9504964262869539
# Training Logistic Regression with C = 16.000999999999998
#   roc_auc_score = 0.9505149669512658
# Training Logistic Regression with C = 17.000999999999998
#   roc_auc_score = 0.9504778856226419
# Training Logistic Regression with C = 18.000999999999998
#   roc_auc_score = 0.9504964262869539
# Training Logistic Regression with C = 19.000999999999998
#   roc_auc_score = 0.9505056966191099
# Training Logistic Regression with C = 20.000999999999998
#   roc_auc_score = 0.9505056966191099
# Training Logistic Regression with C = 21.000999999999998
#   roc_auc_score = 0.9505705889442018
# Training Logistic Regression with C = 22.000999999999998
#   roc_auc_score = 0.9505335076155778
# Training Logistic Regression with C = 23.000999999999998
#   roc_auc_score = 0.9505056966191098
# Training Logistic Regression with C = 24.000999999999998
#   roc_auc_score = 0.9505335076155779
# Training Logistic Regression with C = 25.000999999999998
#   roc_auc_score = 0.9505427779477338
# Training Logistic Regression with C = 26.000999999999998
#   roc_auc_score = 0.9505798592763579
# Training Logistic Regression with C = 27.000999999999998
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 28.000999999999998
#   roc_auc_score = 0.9505705889442018
# Training Logistic Regression with C = 29.000999999999998
#   roc_auc_score = 0.9505427779477338
# Training Logistic Regression with C = 30.000999999999998
#   roc_auc_score = 0.9505335076155779
# Training Logistic Regression with C = 31.000999999999998
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 32.001
#   roc_auc_score = 0.9505891296085138
# Training Logistic Regression with C = 33.00099999999999
#   roc_auc_score = 0.95064475160145
# Training Logistic Regression with C = 34.00099999999999
#   roc_auc_score = 0.9506725625979179
# Training Logistic Regression with C = 35.00099999999999
#   roc_auc_score = 0.9506725625979179
# Training Logistic Regression with C = 36.00099999999999
#   roc_auc_score = 0.9506354812692939
# Training Logistic Regression with C = 37.00099999999999
#   roc_auc_score = 0.9506540219336059
# Training Logistic Regression with C = 38.00099999999999
#   roc_auc_score = 0.9506169406049818
# Training Logistic Regression with C = 39.00099999999999
#   roc_auc_score = 0.9506262109371377
# Training Logistic Regression with C = 40.00099999999999
#   roc_auc_score = 0.9506169406049819
# Training Logistic Regression with C = 41.00099999999999
#   roc_auc_score = 0.9506076702728259
# Training Logistic Regression with C = 42.00099999999999
#   roc_auc_score = 0.9506169406049819
# Training Logistic Regression with C = 43.00099999999999
#   roc_auc_score = 0.9506076702728258
# Training Logistic Regression with C = 44.00099999999999
#   roc_auc_score = 0.9505798592763579
# Training Logistic Regression with C = 45.00099999999999
#   roc_auc_score = 0.9505798592763578
# Training Logistic Regression with C = 46.00099999999999
#   roc_auc_score = 0.950570588944202
# Training Logistic Regression with C = 47.00099999999999
#   roc_auc_score = 0.9505798592763579
# Training Logistic Regression with C = 48.00099999999999
#   roc_auc_score = 0.9505705889442019
# Training Logistic Regression with C = 49.00099999999999
#   roc_auc_score = 0.9505705889442019
# Training Logistic Regression with C = 50.00099999999999
#   roc_auc_score = 0.9505705889442019
# Training Logistic Regression with C = 51.00099999999999
#   roc_auc_score = 0.95059839994067
# Training Logistic Regression with C = 52.00099999999999
#   roc_auc_score = 0.9505891296085139
# Training Logistic Regression with C = 53.00099999999999
#   roc_auc_score = 0.9506169406049818
# Training Logistic Regression with C = 54.00099999999999
#   roc_auc_score = 0.9505983999406699
# Training Logistic Regression with C = 55.00099999999999
#   roc_auc_score = 0.9505705889442019
# Training Logistic Regression with C = 56.00099999999999
#   roc_auc_score = 0.9505891296085138
# Training Logistic Regression with C = 57.00099999999999
#   roc_auc_score = 0.9505891296085138
# Training Logistic Regression with C = 58.00099999999999
#   roc_auc_score = 0.95059839994067
# Training Logistic Regression with C = 59.00099999999999
#   roc_auc_score = 0.9505798592763579
# Training Logistic Regression with C = 60.00099999999999
#   roc_auc_score = 0.9505891296085139
# Training Logistic Regression with C = 61.00099999999999
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 62.00099999999999
#   roc_auc_score = 0.950570588944202
# Training Logistic Regression with C = 63.00099999999999
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 64.00099999999999
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 65.00099999999999
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 66.00099999999999
#   roc_auc_score = 0.9505798592763579
# Training Logistic Regression with C = 67.00099999999999
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 68.00099999999999
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 69.00099999999999
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 70.00099999999999
#   roc_auc_score = 0.9505613186120458
# Training Logistic Regression with C = 71.00099999999999
#   roc_auc_score = 0.9505520482798899
# Training Logistic Regression with C = 72.00099999999999
#   roc_auc_score = 0.9505427779477339
# Training Logistic Regression with C = 73.00099999999999
#   roc_auc_score = 0.9505149669512659
# Training Logistic Regression with C = 74.00099999999999
#   roc_auc_score = 0.9505056966191099
# Training Logistic Regression with C = 75.00099999999999
#   roc_auc_score = 0.9504778856226419
# Training Logistic Regression with C = 76.00099999999999
#   roc_auc_score = 0.9504871559547979
# Training Logistic Regression with C = 77.00099999999999
#   roc_auc_score = 0.9504871559547978
# Training Logistic Regression with C = 78.00099999999999
#   roc_auc_score = 0.9504778856226419
# Training Logistic Regression with C = 79.00099999999999
#   roc_auc_score = 0.9504871559547978
# Training Logistic Regression with C = 80.00099999999999
#   roc_auc_score = 0.9504686152904859
# Training Logistic Regression with C = 81.00099999999999
#   roc_auc_score = 0.9504500746261738
# Training Logistic Regression with C = 82.00099999999999
#   roc_auc_score = 0.9504408042940178
# Training Logistic Regression with C = 83.00099999999999
#   roc_auc_score = 0.9504500746261739
# Training Logistic Regression with C = 84.00099999999999
#   roc_auc_score = 0.9504593449583298
# Training Logistic Regression with C = 85.00099999999999
#   roc_auc_score = 0.9504129932975498
# Training Logistic Regression with C = 86.00099999999999
#   roc_auc_score = 0.9504129932975498
# Training Logistic Regression with C = 87.00099999999999
#   roc_auc_score = 0.9504037229653939
# Training Logistic Regression with C = 88.00099999999999
#   roc_auc_score = 0.9504037229653939
# Training Logistic Regression with C = 89.00099999999999
#   roc_auc_score = 0.9503851823010818
# Training Logistic Regression with C = 90.00099999999999
#   roc_auc_score = 0.9503759119689258
# Training Logistic Regression with C = 91.00099999999999
#   roc_auc_score = 0.9503573713046138
# Training Logistic Regression with C = 92.00099999999999
#   roc_auc_score = 0.9503481009724578
# Training Logistic Regression with C = 93.00099999999999
#   roc_auc_score = 0.9503481009724578
# Training Logistic Regression with C = 94.00099999999999
#   roc_auc_score = 0.9503481009724579
# Training Logistic Regression with C = 95.00099999999999
#   roc_auc_score = 0.9503573713046138
# Training Logistic Regression with C = 96.00099999999999
#   roc_auc_score = 0.9503481009724579
# Training Logistic Regression with C = 97.00099999999999
#   roc_auc_score = 0.9503388306403019
# Training Logistic Regression with C = 98.00099999999999
#   roc_auc_score = 0.9503295603081459
# Training Logistic Regression with C = 99.00099999999999
#   roc_auc_score = 0.9503388306403018
# 34.001 0.950672562598

# %%
lr1_0 = LogisticRegression(fit_intercept=False, C=34)
lr1_0.fit(blslda1.theta, y)
y_lr1_0 = lr1_0.predict_proba(thetas_test_blslda1)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_lr1_0)
plt.plot(fpr, tpr, label=('AUC = {:.3f}'.format(roc_auc_score(y_test, y_lr1_0))))
_ = plt.legend(loc='best')

# %% [markdown]
# #### Gradient boosted trees with SLDA topics

# %%
gbr1_0 = GradientBoostingClassifier()
gbr1_0.fit(blslda1.theta, y)
y_gbr1_0 = gbr1_0.predict_proba(thetas_test_blslda1)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_gbr1_0)
plt.plot(fpr, tpr, label=('AUC = {:.3f}'.format(roc_auc_score(y_test, y_gbr1_0))))
_ = plt.legend(loc='best')

# %% [markdown]
# ### Conclusion for test with fewer topics
#
# BLSLDA performs at least 20% better in AUC than any of the LDA-and-a-regression methods, and similar to the BLSLDA-and-a-logistic-regression methods.
